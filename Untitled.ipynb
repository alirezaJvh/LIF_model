# %%
from LIF.LIF import LIF
import pandas as pd
import matplotlib.pyplot as plt

# %%
parameters = {
    'C': 1,
    'R': 0.12,
    'u_rest': 25,
    'I': 2,
    'threshold': 25.2,
    'start_time': 10,
    'end_time': 150,
    'dt': 0.001
}

# %%
model = LIF(parameters)
sim= model.simulate()
# Out:
# 9

# %%
len(sim['u'])
# Out:
# 150001

# %%
df = pd.DataFrame(sim)

# %%
plt.figure(figsize=(15,5))
plt.plot(sim['time'], sim['u'])
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.plot(sim['time'], parameter)
